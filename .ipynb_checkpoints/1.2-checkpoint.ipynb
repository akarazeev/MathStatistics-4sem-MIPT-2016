# %% [markdown]
# # Task 2

# %%
# %matplotlib inline
import numpy as np
import math as mt
import matplotlib
import matplotlib.pyplot as plt
from pylab import *
from scipy.stats import *

# %%
import random
def RandCol():
    r = lambda: random.randint(0,255)
    return '#%02X%02X%02X' % (r(),r(),r())

def RawMoment(xs, n, k):
    return sum(x**k for x in xs[0:n])/n

# %%
def Exponent(fr, to, h):
    N = 10000
    s_exp = expon.rvs(size=N)
    # Estimate
    est = np.zeros((to-fr+1, N-1))
    for k in range(fr,to+1):
        est[k-fr] = np.array([(mt.factorial(k)/RawMoment(s_exp, n, k))**(1/float(k))\
                              for n in range(1,N)])

    figure()
    ylim(0, h)
    xlabel('Sample size')
    ylabel('$|1-(k!/\overline{X^k})^{(1/k)}|$', fontsize=15)

    for k in range(fr,to+1):
        plot(abs(est[k-fr]-1), 'r', label='k={}'.format(k), color=RandCol())
    legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3, ncol=2, \
               mode="expand", borderaxespad=0.)
    show()

# %%
Exponent(1, 5, 0.05)

# %%
Exponent(6,10,0.3)

# %%
Exponent(11,15,0.3)
