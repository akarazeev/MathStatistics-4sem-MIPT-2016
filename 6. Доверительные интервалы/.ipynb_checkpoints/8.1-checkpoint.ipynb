# %% [markdown]
# # Задача 1

# %%
# %matplotlib inline
import numpy as np
import math as mt
import matplotlib
import matplotlib.pyplot as plt
from pylab import *
from scipy.stats import *

# %%
theta = 1
params = (10, 1)
alpha = 0.95
n = 100

# %% [markdown]
# # Unifrom distribution

# %% [markdown]
# ### Confidence interval with $\overline{X}$

# %%
def Interv1(sample,level):
    return [(mean(sample[:i]))/((1/2) + (1/sqrt(12 * level * i))) for i in range(1,len(sample)+1)]

def Interv2(sample,level):
    return [(mean(sample[:i]))/((1/2) - (1/sqrt(12 * level * i))) for i in range(1,len(sample)+1)]

uni_sample = uniform.rvs(size=n, scale=theta)


fig1 = figure(figsize=(12,5))

ax1 = fig1.add_subplot(111)
ax1.fill_between(arange(1,n+1),Interv1(uni_sample,alpha),Interv2(uni_sample,alpha))

ax2 = fig1.add_subplot(111, sharex=ax1, frameon=False)
ax2.plot([ax1.get_ylim()])
ax2.yaxis.tick_right()

xlabel('Sample size')
title('Parameter={}'.format(theta))

show()

# %% [markdown]
# ### Confidence interval with $X_{(1)}$

# %%
def Interv1(sample,level):
    return [min(sample[:i]) for i in range(1,len(sample)+1)]

def Interv2(sample,level):
    return [min(sample[:i])/(1 - (pow(level,1./i))) for i in range(1,len(sample)+1)]

uni_sample = uniform.rvs(size=n, scale=theta)


fig1 = figure(figsize=(12,5))

ax1 = fig1.add_subplot(111)
ax1.fill_between(arange(1,n+1),Interv1(uni_sample,alpha),Interv2(uni_sample,alpha))

ax2 = fig1.add_subplot(111, sharex=ax1, frameon=False)
ax2.plot([ax1.get_ylim()])
ax2.yaxis.tick_right()

xlabel('Sample size')
title('Parameter={}'.format(theta))
show()

# %% [markdown]
# ### Confidence interval with $X_{(n)}$

# %%
def Interv1(sample,level):
    return [max(sample[:i]) for i in range(1,len(sample)+1)]

def Interv2(sample,level):
    return [max(sample[:i])/(pow(1.-alpha,1./i)) for i in range(1,len(sample)+1)]

uni_sample = uniform.rvs(size=n, scale=theta)


fig1 = figure(figsize=(12,5))

ax1 = fig1.add_subplot(111)
ax1.fill_between(arange(1,n+1),Interv1(uni_sample,alpha),Interv2(uni_sample,alpha))

ax2 = fig1.add_subplot(111, sharex=ax1, frameon=False)
ax2.plot([ax1.get_ylim()])
ax2.yaxis.tick_right()

xlabel('Sample size')
title('Parameter={}'.format(theta))

show()

# %% [markdown]
# # Poisson distribution

# %%
# def Interv1(sample,level):
#     return [max(sample[:i]) for i in range(1,len(sample)+1)]

# def Interv2(sample,level):
#     return [max(sample[:i])/(pow(1.-alpha,1./i)) for i in range(1,len(sample)+1)]

# uni_sample = uniform.rvs(size=n, loc=theta)


# fig1 = figure(figsize=(12,5))

# ax1 = fig1.add_subplot(111)
# ax1.fill_between(arange(1,n+1),Interv1(uni_sample,alpha),Interv2(uni_sample,alpha))

# ax2 = fig1.add_subplot(111, sharex=ax1, frameon=False)
# ax2.plot([ax1.get_ylim()])
# ax2.yaxis.tick_right()

# xlabel('Sample size')
# title('Parameter={}'.format(theta))

# show()

# %% [markdown]
# # Cauchy distribution

# %%
def Interv1(sample,level):
    return [np.median(sample[:i]) - (cauchy.ppf(1-(level/2), loc=theta) \
                                     * (pi/(2*sqrt(i)))) for i in range(1,len(sample)+1)]

def Interv2(sample,level):
    return [np.median(sample[:i]) + (cauchy.ppf(1-(level/2), loc=theta) \
                                     * (pi/(2*sqrt(i)))) for i in range(1,len(sample)+1)]

cau_sample = cauchy.rvs(size=n, loc=theta)

figure(figsize=(12,5))
matplotlib.pyplot.fill_between(arange(1,n+1),Interv1(cau_sample,alpha),Interv2(cau_sample,alpha))
xlabel('Sample size')
title('Parameter={}'.format(theta))
show()

# %% [markdown]
# # Gamma distribution

# %% [markdown]
# ### $\lambda$ is known

# %%
def Interv1(sample,level):
    return [mean(sample[:i]) * (1 - (gamma.ppf((1-level)/2, a=params[0],\
                                   scale=1/params[1])/sqrt(params[1]*i))) for i in range(1,len(sample)+1)]

def Interv2(sample,level):
    return [mean(sample[:i]) * (1 + (gamma.ppf((1+level)/2, a=params[0],\
                                   scale=1/params[1])/sqrt(params[1]*i))) for i in range(1,len(sample)+1)]

gam_sample = gamma.rvs(size=n, a=params[0], scale=1/params[1])


fig1 = figure(figsize=(12,5))

ax1 = fig1.add_subplot(111)
ax1.fill_between(arange(1,n+1),Interv1(gam_sample,alpha),Interv2(gam_sample,alpha))

ax2 = fig1.add_subplot(111, sharex=ax1, frameon=False)
ax2.plot([ax1.get_ylim()])
ax2.yaxis.tick_right()

xlabel('Sample size')
title('Parameter={}'.format(params[0]))

show()
